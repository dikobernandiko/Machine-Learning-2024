# %% [markdown]
# <a href="https://colab.research.google.com/github/dikobernandiko/Machine-Learning-2024/blob/main/minggu4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
csv_file_path = 'Dataset_Sentimen_Emosi.csv'
df = pd.read_csv(csv_file_path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#                                                Tweet  Sentimen  Emosi
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0     -2
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0     -2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Sentimen'].plot(kind='hist', bins=20, title='Sentimen')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Emosi'].plot(kind='hist', bins=20, title='Emosi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
# ...

# %%
import re

# %%
stopwords_list = ['dan', 'di', 'yang', 'untuk', 'dari', 'ke', 'ini', 'itu', 'dengan', 'pada', 'adalah']

# %%
def simple_preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = text.split()
    tokens = [word for word in tokens if word not in stopwords_list]
    processed_text = ' '.join(tokens)
    return processed_text

# %%
df['Processed_Text'] = df['Tweet'].apply(simple_preprocess_text)

# %%
print(df.head())
# Out:
#                                                Tweet  Sentimen  Emosi  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0     -2
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0     -2
#
#                                       Processed_Text
# 0  cegah mata rantai covidmari kita dirumah saja ...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
# 3            covid belum nyampe prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog kerumunan ora...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
df['Emosi'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Distribusi Emosi dalam Dataset')
plt.xlabel('Emosi')
plt.ylabel('Jumlah')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def nltk_preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('indonesian')]
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(word) for word in tokens]
    processed_text = ' '.join(tokens)
    return processed_text

# %%
df['Processed_Text'] = df['Tweet'].apply(nltk_preprocess_text)

# %%
print(df.head())
# Out:
#                                                Tweet  Sentimen  Emosi  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 3            Covid belum nyampe prigen mbak hmm hoax       0.0     -2
# 4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0     -2
#
#                                       Processed_Text
# 0         cegah mata rantai covidmari dirumah minggu
# 1  mohon yaallah semoga wabah covid menghilang ra...
# 2  pemprov papua naikkan statu tanggap darurat co...
# 3                   covid nyamp prigen mbak hmm hoax
# 4  nyuruh orang pintar lu aja togog kerumunan ora...
